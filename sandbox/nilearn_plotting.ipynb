# %%
import numpy as np
from nilearn import plotting
from scipy.spatial.transform import Rotation as R
# Out:
# /home/lukas/anaconda3/envs/deca/lib/python3.8/site-packages/nilearn/datasets/__init__.py:93: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   warn("Fetchers from the nilearn.datasets module will be "

# %%
f = np.load('../pyface/data/faces.npy')
v = np.load('../pyface/data/example_verts.npy')

#r = R.from_rotvec(np.pi/8 * np.array([0, 1, 0]))
#v = r.apply(v)

# right, left
EYES_CENTER = [4597, 4051]
EYES_INNER = [3638, 3835]
EYES_OUTER = [2419, 1142]

# from top to bottom (tip of nose)
NOSE_RIDGE = [
    3516, 3518, 3561, 3548, 3521, 3501, 3508, 3526, 3564
]

EYES_NOSE = EYES_CENTER + EYES_INNER + EYES_OUTER + NOSE_RIDGE

# %%
fig = plotting.plot_surf(
    surf_mesh=[v, f],
#    surf_map=ol,
#    threshold=0.01,
    darkness=1
)
ax = fig.get_axes()[0]
ax.view_init(elev=90, azim=270)
ax.dist = 8
lm = v[EYES_NOSE, :]
ax.scatter(lm[:, 0], lm[:, 1], lm[:, 2])
