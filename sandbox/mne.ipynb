# %%
import mne
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
epochs = mne.read_epochs('../test_data/task-browraiser/sub-01_task-browraiser_epo.fif', verbose=False)
data = epochs.get_data()

# %%
data_rs = data.reshape((10, data.shape[-1], -1, 3))
plt.plot(data_rs[:, :, 103, 0].T)

# %%
from mne.stats import permutation_cluster_1samp_test
m = data.mean(axis=0)
std = data.std(axis=0)
t = m / (std / np.sqrt(10))
t[np.isinf(t)] = 0
t.argmax(axis=1)
#t = permutation_cluster_1samp_test(data, verbose=False)[0]
#t[np.isinf(t)] = 0
# Out:
# /tmp/ipykernel_7506/614612339.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   t = m / (std / np.sqrt(10))
# array([11,  9,  6, ..., 27,  8, 25])
